# %%
import pandas as pd

# %%
df = pd.read_csv(
'../data/anomaly_dump_result.csv', sep=','
)

xlsx = [
    pd.read_excel('../data/Configuration.xlsx'),
    pd.read_excel('../data/GenericAnomaly_dump_result_chunk_8.xlsx'),
    pd.read_excel('../data/GenericAnomaly_dump_result_chunk_7.xlsx'),
    pd.read_excel('../data/GenericAnomaly_dump_result_chunk_6.xlsx'),
    pd.read_excel('../data/GenericAnomaly_dump_result_chunk_5.xlsx'),
    pd.read_excel('../data/GenericAnomaly_dump_result_chunk_4.xlsx'),
    pd.read_excel('../data/GenericAnomaly_dump_result_chunk_3.xlsx'),
    pd.read_excel('../data/GenericAnomaly_dump_result_chunk_2.xlsx'),
    pd.read_excel('../data/GenericAnomaly_dump_result_chunk_1.xlsx')
]

config = pd.read_excel('../data/Configuration.xlsx')
df.head()
# Out:
#   anomaly_kuid\ttitle_txt\tdescription_txt\tsource_application_iua_cod\tcontrol_id\ttypology_id\tdetection_dat\tdetection_time\tdeclaration_time\tasof_dat\tfrequency_typ\tamount_impact_typ\turgency_typ\tpriority_typ\tstatus_typ\trouting_typ\tgolden_source_iua_cod\tremediation_flg\tpre_analysis_flg\tmanaging_application_iua_cod\tassigned_remediator_login_id\tbusiness_data_id\tnotification_method_typ\thotfix_flg\thotfix_expiration_asof_dat\thotfix_starting_asof_dat\tcontributor_ids\tmailing_lists
# 0  ANO00026653D\t0114571\tNULL\tLAK\tFalcon\tFalc...
# 1  ANO00026654D\t1718359\tNULL\tLAK\tFalcon\tFalc...
# 2  ANO00026655D\t0111588\tNULL\tLAK\tFalcon\tFalc...
# 3  ANO00026656D\t0160742\tNULL\tLAK\tFalcon\tFalc...
# 4  ANO00026657D\t0250520\tNULL\tLAK\tFalcon\tFalc...

# %%
anomaly_concat = pd.concat(xlsx)
anomaly_concat.to_csv('../data/anomaly_concat.csv', index=False)
